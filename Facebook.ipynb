# %%
#5. Perform the following operations using Python on the Facebook metrics data sets

# %% [markdown]
# # 5. Perform the following operations using Python on the Facebook metrics data sets

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset_Facebook.csv',delimiter=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# ## Creating Subsets

# %% [markdown]
# ### Subset of type=photo

# %%
df_photo=df.loc[df["Type"]=="Photo"]
df_photo.head(5)
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %% [markdown]
# ### Subset of type=status

# %%
df_status=df.loc[df["Type"]=="Status"]
df_status.head(5)
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df_video=df.loc[df["Type"]=="Video"]
df_video.head(5)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# 183   0.0                      30624                            56950
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df_link=df.loc[df["Type"]=="Link"]
df_link.head(5)
# Out:
#     Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22            138414  Link         1          12             7         10
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 22   0.0                       3454                             6853
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
import os
print("Swarnima")
os.getcwd()
# Out:
# Swarnima
# 'C:\\Users\\SWARNIMA\\Documents\\Facebook metric ass'

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 6A64-9A68
#
#  Directory of C:\Users\SWARNIMA\Documents\Facebook metric ass
#
# 16-05-22  13:21    <DIR>          .
# 16-05-22  13:21    <DIR>          ..
# 16-05-22  12:49    <DIR>          .ipynb_checkpoints
# 16-05-22  12:48            37,891 dataset_Facebook.csv
# 16-05-22  13:21            81,151 Facebook.ipynb
#                2 File(s)        119,042 bytes
#                3 Dir(s)  393,656,811,520 bytes free

# %%
# %%HTML
# <h1> Hello </h1>
# Out:
# <h1> Hello </h1>

# %%
# !mkdir fb

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 6A64-9A68
#
#  Directory of C:\Users\SWARNIMA\Documents\Facebook metric ass
#
# 16-05-22  13:24    <DIR>          .
# 16-05-22  13:24    <DIR>          ..
# 16-05-22  12:49    <DIR>          .ipynb_checkpoints
# 16-05-22  12:48            37,891 dataset_Facebook.csv
# 16-05-22  13:23            87,908 Facebook.ipynb
# 16-05-22  13:24    <DIR>          fb
#                2 File(s)        125,799 bytes
#                4 Dir(s)  393,655,562,240 bytes free

# %%
# %timeit print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# # Merge Data

# %% [markdown]
# ### Merging subsets of photos and status

# %%
df_merged_ps=pd.concat([df_status,df_photo])
df_merged_ps
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
print("Shape of photo subset:")
df_photo.shape
# Out:
# Shape of photo subset:
# (426, 19)

# %%
print("Shape of status subset:")
df_status.shape
# Out:
# Shape of status subset:
# (45, 19)

# %%
print("Shape of merged subset:")
df_merged_ps.shape
# Out:
# Shape of merged subset:
# (471, 19)

# %% [markdown]
# # Sort the Data

# %%
# sorting the data by likes
df_sort_like=df.sort_values(by=["like"])
df_sort_like
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 417            104070  Photo         1           3             3         10
# 100            137020  Photo         1          10             4          9
# 76             137893  Photo         1          11             3          2
# 441             98195  Photo         1           3             5          4
# ..                ...    ...       ...         ...           ...        ...
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
#sorting the data by comments
df_sort_comments=df.sort_values(by=["comment"])
df_sort_comments
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 111            136736   Photo         1          10             6          8
# 276            126424   Photo         3           7             3          4
# 282            126345  Status         2           6             7         11
# 286            126141   Photo         1           6             5         11
# ..                ...     ...       ...         ...           ...        ...
# 228            131728   Photo         2           7             4          3
# 288            126141   Photo         1           6             4         12
# 168            135428   Photo         1           9             3         10
# 460             92507   Photo         3           2             1         13
# 244            130791   Photo         2           7             3          5
#
# ...

# %%
#sorting the data by share
df_sort_share=df.sort_values(by=["share"])
df_sort_share
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 441             98195  Photo         1           3             5          4
# 21             138414  Photo         1          12             7         10
# 436            100732  Photo         1           3             6         13
# 431            100732  Photo         1           3             7         12
# 117            136642  Photo         1          10             7         11
# ..                ...    ...       ...         ...           ...        ...
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
# 120            136393  Photo         1          10             7          9
# 124            136393  Photo         1          10             7          6
# 164            135428  Photo         1           9             5         10
#
# ...

# %% [markdown]
# # Transposing the data(Intercanging the rows and columns)

# %%
df_transpose=df.transpose()

# %%
df_transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df_transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# # Shape and re-shape the data

# %%
ds=np.array([1,2,3,4,5,6])
ds.shape
# Out:
# (6,)

# %%
ds1=ds.reshape(3,2)
ds1
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
df.shape
# Out:
# (500, 19)

# %%
ds
# Out:
# array([1, 2, 3, 4, 5, 6])
